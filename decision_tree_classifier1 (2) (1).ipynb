# %%
import pandas as pd
import numpy as np
df=pd.read_csv("https://raw.githubusercontent.com/shrikant-temburwar/Wine-Quality-Dataset/master/winequality-red.csv",sep = ';')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.shape
# Out:
# (1599, 12)

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
len(df['quality'].unique())
# Out:
# 6

# %%
df['quality'].nunique()
# Out:
# 6

# %%
df['quality'].value_counts()
# Out:
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 240

# %%
df[df.duplicated()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4                    11.0                  34.0  0.99780  3.51       0.56
# 11                   17.0                 102.0  0.99780  3.35       0.80
# 27                   10.0                  37.0  0.99660  3.17       0.91
# 40                   12.0                  87.0  0.99780  3.33       0.83
# 65                    4.0                  11.0  0.99620  3.41       0.39
# ...                   ...                   ...      ...   ...        ...
# 1563                 12.0                  20.0  0.99546  3.29       0.54
# 1564                 12.0                  20.0  0.99546  3.29       0.54
# 1567                 12.0                  20.0  0.99546  3.29       0.54
# 1581                 24.0                  32.0  0.99402  3.54       0.60
# 1596                 29.0                  40.0  0.99574  3.42       0.75
#
#       alcohol  quality
# 4         9.4        5
# 11       10.5        5
# 27        9.5        5
# 40       10.5        5
# 65       10.9        5
# ...       ...      ...
# 1563     10.1        5
# 1564     10.1        5
# 1567     10.1        5
# 1581     11.3        5
# 1596     11.0        6
#
# [240 rows x 12 columns]

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# fixed acidity          7.90000   9.200000   15.90000
# volatile acidity       0.52000   0.640000    1.58000
# citric acid            0.26000   0.420000    1.00000
# residual sugar         2.20000   2.600000   15.50000
# chlorides              0.07900   0.090000    0.61100
# free sulfur dioxide   14.00000  21.000000   72.00000
# total sulfur dioxide  38.00000  62.000000  289.00000
# density                0.99675   0.997835    1.00369
# pH                     3.31000   3.400000    4.01000
# sulphates              0.62000   0.730000    2.00000
# alcohol               10.20000  11.100000   14.90000
# quality                6.00000   6.000000    8.00000

# %%
df.duplicated().sum()
# Out:
# 240

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
X=df.drop("quality",axis=1)

# %%
y=df['quality']

# %%
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=10)

# %%
'''from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import StandardScaler
sclr = StandardScaler()
scr.fit()
scr.transform()'''
# Out:
# 'from sklearn.preprocessing import StandardScaler\nfrom sklearn.preprocessing import StandardScaler\nsclr = StandardScaler()\nscr.fit()\nscr.transform()'

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_train,y_train)
# Out:
# 1.0

# %%
from sklearn import tree
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(25,15))
tree.plot_tree(model, max_depth=4,filled=True)
# Out:
# [Text(0.5219298245614035, 0.9166666666666666, 'x[10] <= 10.15\ngini = 0.645\nsamples = 910\nvalue = [7.0, 31.0, 389.0, 359.0, 114.0, 10.0]'),
#  Text(0.27631578947368424, 0.75, 'x[6] <= 62.5\ngini = 0.495\nsamples = 459\nvalue = [3, 15, 298, 131, 12, 0]'),
#  Text(0.3991228070175439, 0.8333333333333333, 'True  '),
#  Text(0.14035087719298245, 0.5833333333333334, 'x[1] <= 0.548\ngini = 0.571\nsamples = 282\nvalue = [3.0, 11.0, 151.0, 105.0, 12.0, 0.0]'),
#  Text(0.07017543859649122, 0.4166666666666667, 'x[9] <= 0.585\ngini = 0.596\nsamples = 136\nvalue = [1, 4, 52, 68, 11, 0]'),
#  Text(0.03508771929824561, 0.25, 'x[7] <= 0.996\ngini = 0.512\nsamples = 44\nvalue = [0, 4, 28, 12, 0, 0]'),
#  Text(0.017543859649122806, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.05263157894736842, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.10526315789473684, 0.25, 'x[7] <= 0.996\ngini = 0.547\nsamples = 92\nvalue = [1, 0, 24, 56, 11, 0]'),
#  Text(0.08771929824561403, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.12280701754385964, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.21052631578947367, 0.4166666666666667, 'x[7] <= 0.996\ngini = 0.473\nsamples = 146\nvalue = [2, 7, 99, 37, 1, 0]'),
#  Text(0.17543859649122806, 0.25, 'x[10] <= 9.15\ngini = 0.176\nsamples = 32\nvalue = [1, 1, 29, 1, 0, 0]'),
#  Text(0.15789473684210525, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.19298245614035087, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.24561403508771928, 0.25, 'x[10] <= 9.95\ngini = 0.52\nsamples = 114\nvalue = [1, 6, 70, 36, 1, 0]'),
#  Text(0.22807017543859648, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.2631578947368421, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.41228070175438597, 0.5833333333333334, 'x[6] <= 98.5\ngini = 0.288\nsamples = 177\nvalue = [0, 4, 147, 26, 0, 0]'),
#  Text(0.3508771929824561, 0.4166666666666667, 'x[10] <= 9.45\ngini = 0.39\nsamples = 116\nvalue = [0, 4, 87, 25, 0, 0]'),
#  Text(0.3157894736842105, 0.25, 'x[8] <= 3.495\ngini = 0.222\nsamples = 49\nvalue = [0.0, 2.0, 43.0, 4.0, 0.0, 0.0]'),
#  Text(0.2982456140350877, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.3333333333333333, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.38596491228070173, 0.25, 'x[1] <= 0.415\ngini = 0.47\nsamples = 67\nvalue = [0, 2, 44, 21, 0, 0]'),
#  Text(0.3684210526315789, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.40350877192982454, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.47368421052631576, 0.4166666666666667, 'x[4] <= 0.067\ngini = 0.032\nsamples = 61\nvalue = [0, 0, 60, 1, 0, 0]'),
#  Text(0.45614035087719296, 0.25, 'x[4] <= 0.059\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.43859649122807015, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.47368421052631576, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.49122807017543857, 0.25, 'gini = 0.0\nsamples = 59\nvalue = [0, 0, 59, 0, 0, 0]'),
#  Text(0.7675438596491229, 0.75, 'x[9] <= 0.675\ngini = 0.651\nsamples = 451\nvalue = [4.0, 16.0, 91.0, 228.0, 102.0, 10.0]'),
#  Text(0.6447368421052632, 0.8333333333333333, '  False'),
#  Text(0.631578947368421, 0.5833333333333334, 'x[10] <= 11.45\ngini = 0.636\nsamples = 250\nvalue = [4, 16, 69, 130, 29, 2]'),
#  Text(0.5614035087719298, 0.4166666666666667, 'x[1] <= 0.827\ngini = 0.649\nsamples = 157\nvalue = [4.0, 13.0, 60.0, 69.0, 10.0, 1.0]'),
#  Text(0.5263157894736842, 0.25, 'x[3] <= 1.85\ngini = 0.589\nsamples = 134\nvalue = [0, 3, 54, 66, 10, 1]'),
#  Text(0.5087719298245614, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.543859649122807, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.5964912280701754, 0.25, 'x[10] <= 10.95\ngini = 0.696\nsamples = 23\nvalue = [4, 10, 6, 3, 0, 0]'),
#  Text(0.5789473684210527, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.6140350877192983, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.7017543859649122, 0.4166666666666667, 'x[3] <= 4.5\ngini = 0.518\nsamples = 93\nvalue = [0, 3, 9, 61, 19, 1]'),
#  Text(0.6666666666666666, 0.25, 'x[6] <= 15.5\ngini = 0.442\nsamples = 80\nvalue = [0, 1, 8, 58, 12, 1]'),
#  Text(0.6491228070175439, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.6842105263157895, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.7368421052631579, 0.25, 'x[2] <= 0.405\ngini = 0.627\nsamples = 13\nvalue = [0, 2, 1, 3, 7, 0]'),
#  Text(0.7192982456140351, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.7543859649122807, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.9035087719298246, 0.5833333333333334, 'x[10] <= 12.05\ngini = 0.617\nsamples = 201\nvalue = [0, 0, 22, 98, 73, 8]'),
#  Text(0.8421052631578947, 0.4166666666666667, 'x[1] <= 0.335\ngini = 0.589\nsamples = 164\nvalue = [0, 0, 21, 90, 50, 3]'),
#  Text(0.8070175438596491, 0.25, 'x[9] <= 0.735\ngini = 0.59\nsamples = 50\nvalue = [0, 0, 5, 18, 26, 1]'),
#  Text(0.7894736842105263, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.8245614035087719, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.8771929824561403, 0.25, 'x[3] <= 4.4\ngini = 0.537\nsamples = 114\nvalue = [0, 0, 16, 72, 24, 2]'),
#  Text(0.8596491228070176, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.8947368421052632, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.9649122807017544, 0.4166666666666667, 'x[9] <= 0.905\ngini = 0.548\nsamples = 37\nvalue = [0, 0, 1, 8, 23, 5]'),
#  Text(0.9473684210526315, 0.25, 'x[10] <= 13.8\ngini = 0.498\nsamples = 34\nvalue = [0, 0, 1, 5, 23, 5]'),
#  Text(0.9298245614035088, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.9649122807017544, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.9824561403508771, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]')]

# %%
fig.savefig("decistion_tree_classifier.png")

# %%
y_predict=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.5077951002227171

# %%
grid_param = {
    'criterion': ['gini', 'entropy'],
    'max_depth' : range(2,10,1),
    'min_samples_leaf' : range(1,8,1),
    'min_samples_split': range(2,8,1),
    'splitter' : ['best', 'random']

}

# %%
from sklearn.model_selection import GridSearchCV

grid_searh = GridSearchCV(estimator = model, param_grid = grid_param, cv=3, verbose=1)

# %%
grid_searh.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 1344 candidates, totalling 4032 fits
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 10),
#                          'min_samples_leaf': range(1, 8),
#                          'min_samples_split': range(2, 8),
#                          'splitter': ['best', 'random']},
#              verbose=1)

# %%
grid_searh = GridSearchCV(estimator = model, param_grid = grid_param, cv=3, verbose=3)

# %%
grid_searh.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 1344 candidates, totalling 4032 fits
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.543 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.531 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.498 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=3, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=3, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=3, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=3, splitter=random;, score=0.530 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=3, splitter=random;, score=0.561 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=3, splitter=random;, score=0.525 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=4, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=4, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=4, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=4, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=4, splitter=random;, score=0.548 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=4, splitter=random;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=0.520 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=0.498 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=0.535 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=6, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=6, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=6, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=6, splitter=random;, score=0.546 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=6, splitter=random;, score=0.535 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=6, splitter=random;, score=0.564 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=7, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=7, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=7, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=7, splitter=random;, score=0.543 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=7, splitter=random;, score=0.515 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=1, min_samples_split=7, splitter=random;, score=0.538 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=0.549 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=0.535 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=0.495 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=3, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=3, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=3, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=3, splitter=random;, score=0.559 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=3, splitter=random;, score=0.528 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=3, splitter=random;, score=0.607 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=4, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=4, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=4, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=4, splitter=random;, score=0.493 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=4, splitter=random;, score=0.538 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=4, splitter=random;, score=0.455 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=0.539 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=0.462 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=0.485 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=6, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=6, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=6, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=6, splitter=random;, score=0.526 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=6, splitter=random;, score=0.571 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=6, splitter=random;, score=0.492 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=7, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=7, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=7, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=7, splitter=random;, score=0.441 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=7, splitter=random;, score=0.538 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=2, min_samples_split=7, splitter=random;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=2, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=2, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=2, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=2, splitter=random;, score=0.549 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=2, splitter=random;, score=0.531 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=2, splitter=random;, score=0.436 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=3, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=3, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=3, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=3, splitter=random;, score=0.556 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=3, splitter=random;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=3, splitter=random;, score=0.578 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=4, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=4, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=4, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=4, splitter=random;, score=0.539 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=4, splitter=random;, score=0.446 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=4, splitter=random;, score=0.488 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=5, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=5, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=5, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=5, splitter=random;, score=0.536 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=5, splitter=random;, score=0.545 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=5, splitter=random;, score=0.505 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=6, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=6, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=6, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=6, splitter=random;, score=0.549 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=6, splitter=random;, score=0.488 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=6, splitter=random;, score=0.548 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=7, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=7, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=7, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=7, splitter=random;, score=0.507 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=7, splitter=random;, score=0.554 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=3, min_samples_split=7, splitter=random;, score=0.518 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=0.543 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=0.482 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=3, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=3, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=3, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=3, splitter=random;, score=0.576 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=3, splitter=random;, score=0.521 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=3, splitter=random;, score=0.561 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=4, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=4, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=4, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=4, splitter=random;, score=0.562 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=4, splitter=random;, score=0.508 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=4, splitter=random;, score=0.485 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=0.539 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=0.515 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=0.568 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=6, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=6, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=6, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=6, splitter=random;, score=0.490 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=6, splitter=random;, score=0.568 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=6, splitter=random;, score=0.611 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=7, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=7, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=7, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=7, splitter=random;, score=0.516 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=7, splitter=random;, score=0.528 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=7, splitter=random;, score=0.488 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.493 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.531 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=3, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=3, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=3, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=3, splitter=random;, score=0.457 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=3, splitter=random;, score=0.548 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=3, splitter=random;, score=0.607 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=4, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=4, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=4, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=4, splitter=random;, score=0.539 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=4, splitter=random;, score=0.512 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=4, splitter=random;, score=0.482 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.513 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.465 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.568 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=6, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=6, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=6, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=6, splitter=random;, score=0.526 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=6, splitter=random;, score=0.528 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=6, splitter=random;, score=0.561 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=7, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=7, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=7, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=7, splitter=random;, score=0.533 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=7, splitter=random;, score=0.515 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=7, splitter=random;, score=0.452 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=2, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=2, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=2, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=2, splitter=random;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=2, splitter=random;, score=0.521 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=2, splitter=random;, score=0.538 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=3, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=3, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=3, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=3, splitter=random;, score=0.539 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=3, splitter=random;, score=0.459 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=3, splitter=random;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=4, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=4, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=4, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=4, splitter=random;, score=0.480 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=4, splitter=random;, score=0.455 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=4, splitter=random;, score=0.564 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=5, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=5, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=5, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=5, splitter=random;, score=0.493 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=5, splitter=random;, score=0.498 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=5, splitter=random;, score=0.531 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=0.539 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=0.518 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=0.601 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=7, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=7, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=7, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=7, splitter=random;, score=0.536 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=7, splitter=random;, score=0.498 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=6, min_samples_split=7, splitter=random;, score=0.607 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=2, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=2, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=2, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=2, splitter=random;, score=0.516 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=2, splitter=random;, score=0.581 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=2, splitter=random;, score=0.545 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=3, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=3, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=3, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=3, splitter=random;, score=0.559 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=3, splitter=random;, score=0.561 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=3, splitter=random;, score=0.581 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=4, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=4, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=4, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=4, splitter=random;, score=0.579 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=4, splitter=random;, score=0.571 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=4, splitter=random;, score=0.551 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=5, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=5, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=5, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=5, splitter=random;, score=0.543 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=5, splitter=random;, score=0.568 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=5, splitter=random;, score=0.521 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=6, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=6, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=6, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=6, splitter=random;, score=0.477 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=6, splitter=random;, score=0.548 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=6, splitter=random;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=7, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=7, splitter=best;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=7, splitter=best;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=7, splitter=random;, score=0.539 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=7, splitter=random;, score=0.521 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=2, min_samples_leaf=7, min_samples_split=7, splitter=random;, score=0.538 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.536 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.556 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.584 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.518 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=3, splitter=best;, score=0.536 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=3, splitter=best;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=3, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=3, splitter=random;, score=0.556 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=3, splitter=random;, score=0.518 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=3, splitter=random;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=4, splitter=best;, score=0.536 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=4, splitter=best;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=4, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=4, splitter=random;, score=0.546 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=4, splitter=random;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=4, splitter=random;, score=0.492 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=0.536 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=0.572 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=0.508 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=6, splitter=best;, score=0.536 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=6, splitter=best;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=6, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=6, splitter=random;, score=0.546 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=6, splitter=random;, score=0.518 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=6, splitter=random;, score=0.551 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=7, splitter=best;, score=0.536 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=7, splitter=best;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=7, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=7, splitter=random;, score=0.507 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=7, splitter=random;, score=0.561 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=1, min_samples_split=7, splitter=random;, score=0.594 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=0.546 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=0.513 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=0.554 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=0.564 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=3, splitter=best;, score=0.546 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=3, splitter=best;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=3, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=3, splitter=random;, score=0.526 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=3, splitter=random;, score=0.548 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=3, splitter=random;, score=0.624 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=4, splitter=best;, score=0.546 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=4, splitter=best;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=4, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=4, splitter=random;, score=0.553 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=4, splitter=random;, score=0.561 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=4, splitter=random;, score=0.597 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=0.546 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=5, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=0.539 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=0.528 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=5, splitter=random;, score=0.564 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=6, splitter=best;, score=0.546 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=6, splitter=best;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=6, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=6, splitter=random;, score=0.539 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=6, splitter=random;, score=0.571 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=6, splitter=random;, score=0.587 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=7, splitter=best;, score=0.546 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=7, splitter=best;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=7, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=7, splitter=random;, score=0.559 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=7, splitter=random;, score=0.587 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=2, min_samples_split=7, splitter=random;, score=0.558 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=2, splitter=best;, score=0.546 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=2, splitter=best;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=2, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=2, splitter=random;, score=0.546 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=2, splitter=random;, score=0.601 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=2, splitter=random;, score=0.584 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=3, splitter=best;, score=0.546 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=3, splitter=best;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=3, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=3, splitter=random;, score=0.562 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=3, splitter=random;, score=0.568 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=3, splitter=random;, score=0.554 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=4, splitter=best;, score=0.546 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=4, splitter=best;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=4, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=4, splitter=random;, score=0.490 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=4, splitter=random;, score=0.554 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=4, splitter=random;, score=0.505 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=5, splitter=best;, score=0.546 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=5, splitter=best;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=5, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=5, splitter=random;, score=0.586 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=5, splitter=random;, score=0.531 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=5, splitter=random;, score=0.584 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=6, splitter=best;, score=0.546 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=6, splitter=best;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=6, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=6, splitter=random;, score=0.562 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=6, splitter=random;, score=0.581 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=6, splitter=random;, score=0.587 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=7, splitter=best;, score=0.546 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=7, splitter=best;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=7, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=7, splitter=random;, score=0.543 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=7, splitter=random;, score=0.601 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=7, splitter=random;, score=0.502 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=0.546 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=0.536 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=0.561 total time=   0.0s
# ...
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=6, splitter=random;, score=0.611 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=7, splitter=best;, score=0.526 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=7, splitter=best;, score=0.512 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=7, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=7, splitter=random;, score=0.586 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=7, splitter=random;, score=0.568 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=7, splitter=random;, score=0.564 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.543 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.545 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.518 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.530 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.528 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.551 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=3, splitter=best;, score=0.549 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=3, splitter=best;, score=0.525 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=3, splitter=best;, score=0.512 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=3, splitter=random;, score=0.536 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=3, splitter=random;, score=0.551 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=3, splitter=random;, score=0.587 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=4, splitter=best;, score=0.539 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=4, splitter=best;, score=0.508 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=4, splitter=best;, score=0.512 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=4, splitter=random;, score=0.569 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=4, splitter=random;, score=0.568 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=4, splitter=random;, score=0.541 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.543 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.535 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.518 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.549 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.541 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.551 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=6, splitter=best;, score=0.536 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=6, splitter=best;, score=0.545 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=6, splitter=best;, score=0.521 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=6, splitter=random;, score=0.503 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=6, splitter=random;, score=0.561 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=6, splitter=random;, score=0.611 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=7, splitter=best;, score=0.549 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=7, splitter=best;, score=0.535 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=7, splitter=best;, score=0.512 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=7, splitter=random;, score=0.543 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=7, splitter=random;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=5, min_samples_split=7, splitter=random;, score=0.554 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=2, splitter=best;, score=0.562 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=2, splitter=best;, score=0.488 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=2, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=2, splitter=random;, score=0.526 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=2, splitter=random;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=2, splitter=random;, score=0.564 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=3, splitter=best;, score=0.562 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=3, splitter=best;, score=0.505 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=3, splitter=best;, score=0.525 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=3, splitter=random;, score=0.553 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=3, splitter=random;, score=0.538 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=3, splitter=random;, score=0.558 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=4, splitter=best;, score=0.562 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=4, splitter=best;, score=0.485 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=4, splitter=best;, score=0.531 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=4, splitter=random;, score=0.474 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=4, splitter=random;, score=0.538 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=4, splitter=random;, score=0.541 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=5, splitter=best;, score=0.586 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=5, splitter=best;, score=0.505 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=5, splitter=best;, score=0.538 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=5, splitter=random;, score=0.497 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=5, splitter=random;, score=0.584 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=5, splitter=random;, score=0.558 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=0.562 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=0.505 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=0.546 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=0.488 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=0.548 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=7, splitter=best;, score=0.566 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=7, splitter=best;, score=0.505 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=7, splitter=best;, score=0.525 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=7, splitter=random;, score=0.500 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=7, splitter=random;, score=0.597 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=6, min_samples_split=7, splitter=random;, score=0.531 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=2, splitter=best;, score=0.543 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=2, splitter=best;, score=0.512 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=2, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=2, splitter=random;, score=0.523 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=2, splitter=random;, score=0.558 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=2, splitter=random;, score=0.545 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=3, splitter=best;, score=0.543 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=3, splitter=best;, score=0.498 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=3, splitter=best;, score=0.521 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=3, splitter=random;, score=0.576 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=3, splitter=random;, score=0.564 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=3, splitter=random;, score=0.548 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=4, splitter=best;, score=0.539 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=4, splitter=best;, score=0.495 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=4, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=4, splitter=random;, score=0.490 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=4, splitter=random;, score=0.508 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=4, splitter=random;, score=0.545 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=5, splitter=best;, score=0.543 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=5, splitter=best;, score=0.508 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=5, splitter=best;, score=0.521 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=5, splitter=random;, score=0.543 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=5, splitter=random;, score=0.568 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=5, splitter=random;, score=0.591 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=6, splitter=best;, score=0.543 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=6, splitter=best;, score=0.518 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=6, splitter=best;, score=0.521 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=6, splitter=random;, score=0.556 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=6, splitter=random;, score=0.535 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=6, splitter=random;, score=0.594 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=7, splitter=best;, score=0.539 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=7, splitter=best;, score=0.512 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=7, splitter=best;, score=0.528 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=7, splitter=random;, score=0.549 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=7, splitter=random;, score=0.545 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=9, min_samples_leaf=7, min_samples_split=7, splitter=random;, score=0.558 total time=   0.0s
# C:\Users\Dell\anaconda3\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 10),
#                          'min_samples_leaf': range(1, 8),
#                          'min_samples_split': range(2, 8),
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
grid_searh.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 5,
#  'min_samples_leaf': 5,
#  'min_samples_split': 4,
#  'splitter': 'random'}

# %%
model_with_best_params = DecisionTreeClassifier(criterion = 'entropy', max_depth = 5,min_samples_leaf = 5,min_samples_split = 4,splitter ='random')

# %%
model_with_best_params.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=5,
#                        min_samples_split=4, splitter='random')

# %%
from sklearn import tree
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(25,15))
tree.plot_tree(model_with_best_params,filled=True,fontsize=15)
# Out:
# [Text(0.49702380952380953, 0.9166666666666666, 'x[10] <= 11.595\nentropy = 1.721\nsamples = 910\nvalue = [7.0, 31.0, 389.0, 359.0, 114.0, 10.0]'),
#  Text(0.25, 0.75, 'x[10] <= 9.517\nentropy = 1.593\nsamples = 760\nvalue = [7.0, 30.0, 378.0, 282.0, 61.0, 2.0]'),
#  Text(0.37351190476190477, 0.8333333333333333, 'True  '),
#  Text(0.11904761904761904, 0.5833333333333334, 'x[7] <= 0.998\nentropy = 1.041\nsamples = 258\nvalue = [1, 5, 185, 65, 2, 0]'),
#  Text(0.07142857142857142, 0.4166666666666667, 'x[6] <= 125.107\nentropy = 0.939\nsamples = 206\nvalue = [0.0, 4.0, 155.0, 46.0, 1.0, 0.0]'),
#  Text(0.047619047619047616, 0.25, 'x[9] <= 0.626\nentropy = 0.994\nsamples = 186\nvalue = [0, 4, 135, 46, 1, 0]'),
#  Text(0.023809523809523808, 0.08333333333333333, 'entropy = 0.962\nsamples = 139\nvalue = [0, 4, 106, 28, 1, 0]'),
#  Text(0.07142857142857142, 0.08333333333333333, 'entropy = 0.96\nsamples = 47\nvalue = [0, 0, 29, 18, 0, 0]'),
#  Text(0.09523809523809523, 0.25, 'entropy = 0.0\nsamples = 20\nvalue = [0, 0, 20, 0, 0, 0]'),
#  Text(0.16666666666666666, 0.4166666666666667, 'x[6] <= 74.993\nentropy = 1.317\nsamples = 52\nvalue = [1.0, 1.0, 30.0, 19.0, 1.0, 0.0]'),
#  Text(0.14285714285714285, 0.25, 'x[9] <= 0.838\nentropy = 1.444\nsamples = 37\nvalue = [1, 1, 15, 19, 1, 0]'),
#  Text(0.11904761904761904, 0.08333333333333333, 'entropy = 1.161\nsamples = 31\nvalue = [1, 0, 13, 17, 0, 0]'),
#  Text(0.16666666666666666, 0.08333333333333333, 'entropy = 1.918\nsamples = 6\nvalue = [0, 1, 2, 2, 1, 0]'),
#  Text(0.19047619047619047, 0.25, 'entropy = 0.0\nsamples = 15\nvalue = [0, 0, 15, 0, 0, 0]'),
#  Text(0.38095238095238093, 0.5833333333333334, 'x[10] <= 10.054\nentropy = 1.74\nsamples = 502\nvalue = [6, 25, 193, 217, 59, 2]'),
#  Text(0.2857142857142857, 0.4166666666666667, 'x[1] <= 0.56\nentropy = 1.515\nsamples = 175\nvalue = [2, 10, 100, 54, 9, 0]'),
#  Text(0.23809523809523808, 0.25, 'x[5] <= 24.71\nentropy = 1.693\nsamples = 77\nvalue = [1, 4, 30, 34, 8, 0]'),
#  Text(0.21428571428571427, 0.08333333333333333, 'entropy = 1.527\nsamples = 63\nvalue = [0, 2, 21, 33, 7, 0]'),
#  Text(0.2619047619047619, 0.08333333333333333, 'entropy = 1.627\nsamples = 14\nvalue = [1, 2, 9, 1, 1, 0]'),
#  Text(0.3333333333333333, 0.25, 'x[10] <= 9.884\nentropy = 1.196\nsamples = 98\nvalue = [1.0, 6.0, 70.0, 20.0, 1.0, 0.0]'),
#  Text(0.30952380952380953, 0.08333333333333333, 'entropy = 1.113\nsamples = 58\nvalue = [0, 6, 42, 10, 0, 0]'),
#  Text(0.35714285714285715, 0.08333333333333333, 'entropy = 1.126\nsamples = 40\nvalue = [1, 0, 28, 10, 1, 0]'),
#  Text(0.47619047619047616, 0.4166666666666667, 'x[2] <= 0.327\nentropy = 1.757\nsamples = 327\nvalue = [4, 15, 93, 163, 50, 2]'),
#  Text(0.42857142857142855, 0.25, 'x[8] <= 3.506\nentropy = 1.747\nsamples = 185\nvalue = [4, 14, 55, 96, 15, 1]'),
#  Text(0.40476190476190477, 0.08333333333333333, 'entropy = 1.641\nsamples = 154\nvalue = [3, 6, 44, 86, 14, 1]'),
#  Text(0.4523809523809524, 0.08333333333333333, 'entropy = 1.881\nsamples = 31\nvalue = [1, 8, 11, 10, 1, 0]'),
#  Text(0.5238095238095238, 0.25, 'x[9] <= 0.678\nentropy = 1.619\nsamples = 142\nvalue = [0, 1, 38, 67, 35, 1]'),
#  Text(0.5, 0.08333333333333333, 'entropy = 1.581\nsamples = 59\nvalue = [0, 1, 26, 25, 6, 1]'),
#  Text(0.5476190476190477, 0.08333333333333333, 'entropy = 1.431\nsamples = 83\nvalue = [0, 0, 12, 42, 29, 0]'),
#  Text(0.7440476190476191, 0.75, 'x[8] <= 3.374\nentropy = 1.574\nsamples = 150\nvalue = [0, 1, 11, 77, 53, 8]'),
#  Text(0.6205357142857143, 0.8333333333333333, '  False'),
#  Text(0.6428571428571429, 0.5833333333333334, 'x[0] <= 10.354\nentropy = 1.528\nsamples = 92\nvalue = [0, 1, 3, 42, 40, 6]'),
#  Text(0.5952380952380952, 0.4166666666666667, 'x[2] <= 0.112\nentropy = 1.493\nsamples = 75\nvalue = [0, 1, 1, 31, 36, 6]'),
#  Text(0.5714285714285714, 0.25, 'entropy = 1.371\nsamples = 5\nvalue = [0, 0, 1, 1, 3, 0]'),
#  Text(0.6190476190476191, 0.25, 'x[0] <= 6.712\nentropy = 1.427\nsamples = 70\nvalue = [0, 1, 0, 30, 33, 6]'),
#  Text(0.5952380952380952, 0.08333333333333333, 'entropy = 0.592\nsamples = 7\nvalue = [0, 0, 0, 6, 1, 0]'),
#  Text(0.6428571428571429, 0.08333333333333333, 'entropy = 1.445\nsamples = 63\nvalue = [0, 1, 0, 24, 32, 6]'),
#  Text(0.6904761904761905, 0.4166666666666667, 'x[8] <= 3.141\nentropy = 1.261\nsamples = 17\nvalue = [0, 0, 2, 11, 4, 0]'),
#  Text(0.6666666666666666, 0.25, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.7142857142857143, 0.25, 'x[10] <= 11.907\nentropy = 1.459\nsamples = 12\nvalue = [0, 0, 2, 6, 4, 0]'),
#  Text(0.6904761904761905, 0.08333333333333333, 'entropy = 1.149\nsamples = 7\nvalue = [0, 0, 1, 5, 1, 0]'),
#  Text(0.7380952380952381, 0.08333333333333333, 'entropy = 1.371\nsamples = 5\nvalue = [0, 0, 1, 1, 3, 0]'),
#  Text(0.8452380952380952, 0.5833333333333334, 'x[9] <= 0.54\nentropy = 1.485\nsamples = 58\nvalue = [0, 0, 8, 35, 13, 2]'),
#  Text(0.7857142857142857, 0.4166666666666667, 'x[3] <= 1.886\nentropy = 0.971\nsamples = 10\nvalue = [0, 0, 4, 6, 0, 0]'),
#  Text(0.7619047619047619, 0.25, 'entropy = 0.971\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.8095238095238095, 0.25, 'entropy = 0.722\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.9047619047619048, 0.4166666666666667, 'x[9] <= 0.704\nentropy = 1.439\nsamples = 48\nvalue = [0, 0, 4, 29, 13, 2]'),
#  Text(0.8571428571428571, 0.25, 'x[9] <= 0.608\nentropy = 1.149\nsamples = 28\nvalue = [0, 0, 4, 20, 4, 0]'),
#  Text(0.8333333333333334, 0.08333333333333333, 'entropy = 0.592\nsamples = 14\nvalue = [0, 0, 2, 12, 0, 0]'),
#  Text(0.8809523809523809, 0.08333333333333333, 'entropy = 1.379\nsamples = 14\nvalue = [0, 0, 2, 8, 4, 0]'),
#  Text(0.9523809523809523, 0.25, 'x[6] <= 85.211\nentropy = 1.369\nsamples = 20\nvalue = [0, 0, 0, 9, 9, 2]'),
#  Text(0.9285714285714286, 0.08333333333333333, 'entropy = 1.231\nsamples = 15\nvalue = [0, 0, 0, 9, 5, 1]'),
#  Text(0.9761904761904762, 0.08333333333333333, 'entropy = 0.722\nsamples = 5\nvalue = [0, 0, 0, 0, 4, 1]')]

# %%
y_prediction_with_best_params = model_with_best_params.predict(X_test)

# %%
accuracy_score(y_test,y_prediction_with_best_params)
# Out:
# 0.5256124721603563

# %%
#logistic regression, SVM ,  going forward(RF,XB,GB,AB)

# %%
#Implement the decision tree regressor
dataset:https://archive.ics.uci.edu/ml/datasets/individual+household+electric+power+consumption

take_refrence_from_here:https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html#sklearn.tree.DecisionTreeRegressor
